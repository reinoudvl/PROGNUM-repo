# %% [markdown]
# * Name: reinoud van leeuwen
# * Username: rmjleeuwen
# * Student s-number: S6313337
# * Group (AS1, etc.): as3

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %%
from astropy.constants import G

Mmoon = 7.342*10**22
Mearth = 5.9722 *10**24
Rdis = 385000.6*1000

F = (G*Mmoon*Mearth)/(Rdis**2)
print(F)
# Out:
# 1.974384051807571e+20 m3 / (kg s2)

# %% [markdown]
# 1.10

# %% [markdown]
# ![moet%20in%20notebookScreenshot%202025-11-16%20130654.png](attachment:moet%20in%20notebookScreenshot%202025-11-16%20130654.png)
