# %%
x = [1.36,  1.46,  1.41,  2.12,  0.42,  0.98,  0.45,  1.97, -0.24, 2.18]
x.append(0.52)
x.remove(2.12)
print(x[6])
print(x.index(1.41))

slice= x[2::2]
print(slice)
y = slice[:-1]
print(y)

s = sum(y)
n = len(y)
a = s/n
print(s)
print(n)
print(a)
# Out:
# 1.97
# 2
# [1.41, 0.98, 1.97, 2.18]
# [1.41, 0.98, 1.97]
# 4.359999999999999
# 3
# 1.4533333333333331

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]
ng1 = set(night1)
ng2 = set(night2)
inters= list(set.intersection(ng1, ng2))
print(inters)
if int(5) in inters:
    print(f"he is in intersec")
else:
    print(f"he not in intersec")

if int(5) in night1:
    print(f"he is in nacht")
else:
    print(f"he not in naght")
# Out:
# [0, 1, 2, 3, 4]
# he not in intersec
# he is in nacht
